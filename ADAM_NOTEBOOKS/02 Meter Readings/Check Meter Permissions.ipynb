# %%
import pandas as pd
import json as js
import requests
from sqlalchemy import create_engine
from datetime import datetime as dt, timedelta, timezone

# Set Global Variables
ENGINE = create_engine('postgresql://postgres:4raxeGo5xgB$@localhost:5432/eyedro_meters')
API_BASE_URL = "https://api.eyedro.com/customcmd"
USER_KEY = "UNHCRMHiYgbHda9cRv4DuPp28DnAnfeV8s6umP5R"
USER_KEY_GET_DATA = "UNHCRp28DnAV8s6uHdMHiYgba95RcRv4DnfeuPmP"

l_sql_serials = pd.read_sql_query("select * from vw_table_list;",con=ENGINE).serial_num.to_list()

def eyedro_getdata(serial, timestamp):
    meter_url = "https://api.eyedro.com/customcmd?Cmd=Unhcr.GetData&DeviceSerial=" + str(serial) + "&DateStartSecUtc=" + str(timestamp) + f"&DateNumSteps=96&UserKey={USER_KEY_GET_DATA}"
    response = requests.get(meter_url, timeout=600)
    return js.loads(response.text)

timestamp = '1682208000'

li_responses = []
status_list = []

for i in l_sql_serials:
    try:
        tuple_pair = (i, eyedro_getdata(i, timestamp)['Errors'])
        status_list.append(tuple_pair)
        print(f'{i} complete')
    except:
        print(f'{i} failed')

# Push to dataframe
df_errors = pd.DataFrame(status_list, columns=['Serial Number', 'Error'])

# Clean non-error responses
df_errors['Error'] = df_errors['Error'].apply(lambda x: None if x == [] else x)

# Push to excel
df_errors.to_excel('/Users/adamfifield/Desktop/error_file.xlsx')

# Display in console
df_errors
# Out:
# 009808F5 complete
# 00980A35 complete
# 0098092B complete
# 00980753 complete
# 00980641 complete
# 00980831 complete
# 0098089D complete
# 009807B4 complete
# 00980A02 complete
# 00980885 complete
# 00980849 complete
# 00980A47 complete
# 00980B81 complete
# 00980ACB complete
# 009808EA complete
# 0098090F complete
# 0098063D complete
# 009809B5 complete
# 00980869 complete
# 009808B7 complete
# 00980847 complete
# 009809E0 complete
# 0098082E complete
# 00980ABB complete
# 009808A8 complete
# 0098064C complete
# 00980832 complete
# 009808BF complete
# 009809F1 complete
# 009809FC complete
# 00980836 complete
# 00980A48 complete
# 00980845 complete
# 00980AA5 complete
# 00980957 complete
# 00980AD1 complete
# 009809EE complete
# 0098091A complete
# 009807B5 complete
# 009808C7 complete
# 00980A67 complete
# 0098083E complete
# 00980754 complete
# 00980851 complete
# 00980A3F complete
# 00980921 complete
# 00980A03 complete
# 009809F7 complete
# 00980893 complete
# 0098085A complete
# 00980A3C complete
# 00980A99 complete
# 0098078A complete
# 009809EF complete
# 009808E8 complete
# 009808E3 complete
# 009808BC complete
# 009808B8 complete
# 009809CA complete
# 0098089B complete
# 00980899 complete
# 00980A2D complete
# 00980933 complete
# 00980876 complete
# 009808FD complete
# 009808AF complete
# 0098082D complete
# 00980903 complete
# 00980A29 complete
# 00980935 complete
# 00980A2B complete
# 009809E1 complete
# 009808B3 complete
# 00980AC3 complete
# 00980879 complete
# 00980863 complete
# 00980926 complete
# 00980AF4 complete
# 0098064E complete
# 00980834 complete
# 00980A9D complete
# 009809F5 complete
# 009808B0 complete
# 00980A66 complete
# 0098097A complete
# 00980645 complete
# 009808C6 complete
# 00980757 complete
# 0098092F complete
# 00980A31 complete
# 00980AC8 complete
# 00980ACC complete
# 00980868 complete
# 00980887 complete
# 00980759 complete
# 00980B80 complete
# 0098095A complete
# 00980AB7 complete
# 009808BE complete
# 00980A20 complete
# 00980A15 complete
# 0098090B complete
# 009808D5 complete
# 0098093B complete
# 00980850 complete
# 00980915 complete
# 009808E9 complete
# 00980A0B complete
# 0098088B complete
# 00980B00 complete
# 00980870 complete
# 00980A52 complete
# 00980884 complete
# 009808DD complete
# 00980826 complete
# 00980A6B complete
# 009809FA complete
# 00980A22 complete
# 0098089C complete
# 0098092D complete
# 009809E4 complete
# 00980755 complete
# 00980A33 complete
# 009808B9 complete
# 00980820 complete
# 00980916 complete
# 00980A0A complete
# 00980A3D complete
# 00980B2E complete
# 00980937 complete
# 009807D4 complete
# 00980A6A complete
# 00980A53 complete
# 00980A72 complete
# 009809E9 complete
# 00980B36 complete
# 00980B2C complete
# 00980A19 complete
# 00980A4D complete
# 009808F2 complete
# 00980B27 complete
# 009808EB complete
# 00980954 complete
# 00980A4C complete
# 00980830 complete
# 00980B70 complete
# 009809CB complete
# 0098088A complete
# 00980A24 complete
# 00980B29 complete
# 009807DB complete
# 00980A40 complete
# 00980B87 complete
# 00980B84 complete
# 009808BD complete
# 00980ADE complete
# 00980A09 complete
# 0098064A complete
# 00980A69 complete
# 00980B17 complete
# 00980A3E complete
# 00980888 complete
# 0098084C complete
# 00980867 complete
# 00980780 complete
# 00980AB9 complete
# 0098088E complete
# 00980A28 complete
# 00980A1E complete
# 00980902 complete
# 009807F6 complete
# 00980846 complete
# 00980896 complete
# 00980644 complete
# 0098097B complete
# 00980894 complete
# 00980A32 complete
# 009809C7 complete
# 009807D3 complete
# 00980961 complete
# 009808B5 complete
# 00980986 complete
# 00980861 complete
# 00980AC1 complete
# 009808FC complete
# 009808FE complete
# 0098083F complete
# 009809F0 complete
# 00980978 complete
# 0098082F complete
# 00980A74 complete
# 009809B7 complete
# 00980B26 complete
# 009808ED complete
# 00980A0E complete
# 00980882 complete
# 009808F4 complete
# 00980B37 complete
# 0098087B complete
# 00980B35 complete
# 009808F9 complete
# 00980B2A complete
# 009808F1 complete
# 00980B1A complete
# 00980857 complete
# 00980912 complete
# 00980865 complete
# 0098075A complete
# 00980895 complete
# 00980878 complete
# 009807DE complete
# 009809C4 complete
# 00980897 complete
# 00980A76 complete
# 00980A9B complete
# 009809C6 complete
# 0098088C complete
# 00980A49 complete
# 00980A2C complete
# 00980B01 complete
# 0098089E complete
# 0098097C complete
# 009808B2 complete
# 00980981 complete
# 0098087A complete
# 009809DF complete
# 00980A25 complete
# 00980A0D complete
# 00980A6F complete
# 00980786 complete
# 00980840 complete
# 009809ED complete
# 00980982 complete
# 009809FE complete
# 00980640 complete
# 0098083A complete
# 00980A2F complete
# 00980931 complete
# 009809CC complete
# 009807D2 complete
# 00980823 complete
# 00980989 complete
# 009809E6 complete
# 00980AAF complete
# 00980A14 complete
# 0098090C complete
# 0098084F complete
# 009808E2 complete
# 0098074A complete
# 00980A57 complete
# 00980AEE complete
# 00980966 complete
# 009807C4 complete
# 009808BA complete
# 00980AAE complete
# 0098084E complete
# 00980A17 complete
# 00980AA4 complete
# 009808E1 complete
# 0098086F complete
# 00980A34 complete
# 0098092C complete
# 00980875 complete
# 009809C9 complete
# 009809DA complete
# 00980AE6 complete
# 00980858 complete
# 0098085C complete
# 00980A01 complete
# 009809C8 complete
# 00980822 complete
# 00980988 complete
# 009808D9 complete
# 00980905 complete
# 009808DE complete
# 00980A05 complete
# 0098091B complete
# 009808DF complete
# 009808E5 complete
# 00980A0C complete
# 0098097E complete
# 00980B21 complete
# 00980A1B complete
# 0098085B complete
# 00980789 complete
# 00980985 complete
# 009809F6 complete
# 009808A9 complete
# 00980958 complete
# 00980AB3 complete
# 00980824 complete
# 009808DA complete
# 00980936 complete
# 0098085D complete
# 0098086D complete
# 0098088F complete
# 009808DB complete
# 0098086A complete
# 00980871 complete
# 009809EC complete
# 00980967 complete
# 0098086C complete
# 00980B8C complete
# 00980A00 complete
# 00980952 complete
# 009809EA complete
# 009808E0 complete
# 00980859 complete
# 0098078B complete
# 009809FD complete
# 00980835 complete
# 0098064D complete
# 00980AF5 complete
# 00980862 complete
# 009807DA complete
# 009809E2 complete
# 00980927 complete
# 00980AC2 complete
# 009807B3 complete
# 00980A9E complete
# 009809F4 complete
# 00980828 complete
# 009808B1 complete
# 00980B5C complete
# 009809C3 complete
# 009809F3 complete
# 0098084D complete
# 00980A16 complete
# 00980AA2 complete
# 00980907 complete
# 00980874 complete
# 00980A1F complete
# 00980901 complete
# 009808DC complete
# 00980844 complete
# 009809AE complete
# 00980A18 complete
# 0098087F complete
# 00980742 complete
# 00980892 complete
# 00980AA1 complete
# 00980842 complete
# 009809AC complete
# 009808E6 complete
# 009808EF complete
# 00980890 complete
# 0098075B complete
# 00980923 complete
# 00980889 complete
# 00980866 complete
# 009808B6 complete
# 0098083B complete
# 00980839 complete
# 00980841 complete
# 0098084A complete
# 0098082A complete
# 00980904 complete
# 00980A73 complete
# 009808D8 complete
# 00980919 complete
# 0098090D complete
# 00980A13 complete
# 0098079A complete
# 009808C0 complete
# 00980A37 complete
# 0098086E complete
# 00980ADF complete
# 00980AF1 complete
# 00980A68 complete
# 009808C8 complete
# 00980A26 complete
# 0098093A complete
# 00980A0F complete
# 00980911 complete
# 009809A8 complete
# 00980AE3 complete
# 00980A5A complete
# 00980747 complete
# 009808AA complete
# 00980B63 complete
# 00980A21 complete
# 00980AB8 complete
# 0098087C complete
# 009807D9 complete
# 00980852 complete
# 00980A27 complete
# 00980B19 complete
# 0098092A complete
# 00980838 complete
# 0098097F complete
# 009807D5 complete
# 00980881 complete
# 009808F7 complete
# 00980880 complete
# 00980A36 complete
# 0098084B complete
# 00980A10 complete
# 00980873 complete
# 0098083C complete
# 00980A11 complete
# 0098089A complete
# 009808EC complete
# 00980A9C complete
# 009808FB complete
# 00980A1C complete
# 00980883 complete
# 00980A39 complete
# 00980929 complete
# 00980B60 complete
# 0098088D complete
# 00980741 complete
# 00980984 complete
# 009807D8 complete
# 009809F2 complete
# 00980886 complete
# 009808F0 complete
# 00980756 complete
# 00980A30 complete
# 00980891 complete
# 0098082B complete
# 009807F5 complete
# 00980959 complete
# 0098095B complete
# 0098090E complete
# 00980A12 complete
# 00980918 complete
# 0098085F complete
# 009808B4 complete
# 0098087D complete
# 00980910 complete
# 00980A38 complete
# 00980787 complete
# 009809B6 complete
# 00980855 complete
# 00980785 complete
# 00980906 complete
# 00980898 complete
# 00980A2E complete
# 00980932 complete
# 00980A2A complete
# 009809E5 complete
# 0098085E complete
# 00980A50 complete
# 00980872 complete
# 0098089F complete
# 00980925 complete
# 00980860 complete
# 00980837 complete
# 009809FF complete
# 00980A97 complete
# 00980960 complete
# 009809FB complete
# 009809F9 complete
# 00980A75 complete
# 009808D7 complete
# 0098090A complete
# 0098095F complete
# 00980825 complete
# 00980AC9 complete
# 00980A51 complete
# 00980AEC complete
# 009004E2 complete
# 009809D4 complete
# 00980877 complete
# 00980962 complete
# 00980A1A complete
# 00980827 complete
# 00980853 complete
# 00980843 complete
# 009004E6 complete
# 00980AA3 complete
# 00980639 complete
# 0098098D complete
# 00980848 complete
# 00980A4F complete
# 00980B64 complete
# 009809E8 complete
# 009807D6 complete
# 0098086B complete
# 00980AFE complete
# 00980781 complete
# 00980A06 complete
# 00980987 complete
# 00980760 complete
# 00980833 complete
# 009808BB complete
# 009809AD complete
# 00980864 complete
# 009809B8 complete
#     Serial Number Error
# 0        009808F5  None
# 1        00980A35  None
# 2        0098092B  None
# 3        00980753  None
# 4        00980641  None
# ..            ...   ...
# 484      00980833  None
# 485      009808BB  None
# 486      009809AD  None
# 487      00980864  None
# 488      009809B8  None
#
# [489 rows x 2 columns]
